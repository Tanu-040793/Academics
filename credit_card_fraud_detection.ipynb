# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.model_selection
from sklearn.model_selection import train_test_split


data = pd.read_csv('C:\\Users\\ezbanta\\Desktop\\Learnbay_AI_ML_course\\statistics\\Datasets\\creditcard.csv')
data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %% [markdown]
# # EDA

# %%
sns.countplot(x='Class', data=data)
plt.title('Value count of Class')
plt.xticks(np.arange(2),('normal','fraud'))
plt.show()

# %%
#convert to fraud and normal in the dataset

fraud=data[data['Class']==1]
normal=data[data['Class']==0]

# %%
print(fraud.shape)
print(normal.shape)
# Out:
# (492, 31)
# (284315, 31)

# %%
#choose a sample from the data
df=data.sample(frac=0.1, random_state=1)
df.shape
# Out:
# (28481, 31)

# %%
#find the no of fraud and valid trans in the dataset
Fraud=df[df['Class']==1]
Valid=df[df['Class']==0]

outlier= len(Fraud)/float(len(Valid))
print(outlier)
print('Fraud trans : ', len(Fraud))
print('Valid trans : ', len(Valid))
# Out:
# 0.0017234102419808666
# Fraud trans :  49
# Valid trans :  28432

# %%
print('Amount details of fraudulent transaction')
Fraud.Amount.describe()
# Out:
# Amount details of fraudulent transaction
# count      49.000000
# mean      173.505306
# std       387.996569
# min         0.000000
# 25%         1.000000
# 50%         4.900000
# 75%       122.680000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
print('Amount details of Valid transaction')
Valid.Amount.describe()
# Out:
# Amount details of Valid transaction
# count    28432.000000
# mean        89.813898
# std        270.636594
# min          0.000000
# 25%          5.990000
# 50%         22.380000
# 75%         78.820000
# max      19656.530000
# Name: Amount, dtype: float64

# %%
#from the above 2 checks we can clearly see that the mean transaction of the fraud ones are more.

# %%
#find correlation of each feature
corr_det=df.corr()
cor_feature=corr_det.index

#plot heatmap
plt.figure(figsize=(20,30))
plt.title('pearson correlation')
sns.heatmap(data[cor_feature].corr(), annot=True, cmap='RdYlGn')

# %%
#From HeatMap we can clearly see that most of the features do not correlate to other features but there are 
#some features that either has a positive or a negative correlation with each other. For example “V2” and “V5” 
#are highly negatively correlated with the feature called “Amount”. We also see some correlation with “V20” 
#and “Amount”. This gives us a deeper understanding of the Data available to us

# %%
#let's divide the data into feature and target

# %%
#create dependent and independent features
col=df.columns.tolist()
#filter the column we do not want
col=[i for i in col if i not in ['Class']]
#predicting value store
target='Class'
#define random state
state=np.random.RandomState(42)
X=df[col]
Y=df[target]
X_outliers=state.uniform(low=0,high=1,size=(X.shape[0],X.shape[1]))
print(X.shape)
print(Y.shape)
# Out:
# (28481, 30)
# (28481,)

# %% [markdown]
# # Model Prediction

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
from sklearn.metrics import confusion_matrix

# %%
#train test split
X=df.drop(['Class'], axis=1)
y=df['Class']
print(X.shape)
print(y.shape)
X_data=X.values
y_data=y.values
X_train,X_test,y_train,y_test=train_test_split(X_data,y_data,random_state=42,test_size=0.1)
# Out:
# (28481, 30)
# (28481,)

# %%
#Random forest model

forest=RandomForestClassifier()
forest.fit(X_train,y_train)

#prediction
pred=forest.predict(X_test)

pred
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#Evaluate the classifoer
n_outliers = len(Fraud)
n_errors = (pred != y_test).sum()

#Printing the score of the classifier
acc=accuracy_score(y_test,pred)
print('The accuracy is {} '.format(acc))
prec=precision_score(y_test,pred)
print('The precision is {} '.format(prec))
rec= recall_score(y_test,pred)
print('The recall is {}'.format(rec))
f1= f1_score(y_test,pred)
print("The F1-Score is {}".format(f1))
# Out:
# The accuracy is 0.9992979992979993
# The precision is 0.6666666666666666
# The recall is 0.6666666666666666
# The F1-Score is 0.6666666666666666

# %%
#Confusion Matrix
Labels=['Fraud', 'Valid']
conf_matrix=confusion_matrix(y_test, pred)

#plot
plt.figure(figsize=(10,10))
sns.heatmap(conf_matrix, xticklabels=Labels,yticklabels=Labels, annot=True, fmt='d')
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
#classification metrics
plt.figure(figsize=(10, 10))
print('{}: {}'.format('Random Forest', n_errors))
print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# Random Forest: 2
# 0.9992979992979993
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2846
#            1       0.67      0.67      0.67         3
#
#    micro avg       1.00      1.00      1.00      2849
#    macro avg       0.83      0.83      0.83      2849
# weighted avg       1.00      1.00      1.00      2849

# %% [markdown]
# Observations:
#
# As you can clearly see that our model or any model, in general, have a low Recall Value, which is precisely the reason why you get harassed by so many confirmation messages after a transaction.
#
# 1.the model is fast.
# 2.Less complex
# 3.confidentiality of the users are still maintained
# 4.we failed to deal the imbalance data but with that as well the performence is quite good.
